# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Data

# %%
book_path = r"preprocessed_data\book_processed.csv"
rating_path = r"preprocessed_data\rating_processed.csv"
user_data = r"preprocessed_data\user_processed.csv"

# %%
book_df = pd.read_csv(book_path)
book_df.drop(columns=["Unnamed: 0"], inplace=True)
book_df.sort_values(by=["ISBN"], inplace=True)
book_df.reset_index(drop=True, inplace=True)

rating_df = pd.read_csv(rating_path)
rating_df.drop(columns=["Unnamed: 0"], inplace=True)
rating_df.sort_values(by=["User-ID", "ISBN"], inplace=True)
rating_df.reset_index(drop=True, inplace=True)

user_df = pd.read_csv(user_data)
user_df.drop(columns=["Unnamed: 0"], inplace=True)
user_df.sort_values(by=["User-ID"], inplace=True)
user_df.reset_index(drop=True, inplace=True)

print("Books")
display(book_df.head(3))
print("Ratings")
display(rating_df.head(3))
print("Users")
display(user_df.head(3))
# Out:
# Books
#          ISBN                                         Book-Title  \
# 0  0000913154  The Way Things Work: An Illustrated Encycloped...
# 1  0001010565                                    Mog's Christmas
# 2  0001046438                                               Liar
#
#                      Book-Author  Year-Of-Publication             Publisher
# 0  C. van Amerongen (translator)               1967.0  Simon &amp; Schuster
# 1                    Judith Kerr               1992.0               Collins
# 2                    Stephen Fry                  NaN      Harpercollins Uk
# Ratings
#    User-ID        ISBN  Book-Rating
# 0        2  0195153448            0
# 1        8  0002005018            5
# 2        8  0060973129            0
# Users
#    User-ID                         Location  Age
# 0        1               nyc, new york, usa   34
# 1        2        stockton, california, usa   18
# 2        3  moscow, yukon territory, russia   34

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## include book cover images

# %%
from IPython.core.display_functions import display
temp_df = pd.read_csv("dataset\Books.csv")
select_col = ["ISBN", "Image-URL-L"]
temp_df = temp_df[select_col]

book_df = pd.merge(book_df, temp_df, on="ISBN", how="left")

print("Books")
display(book_df.head(3))
# Out:
# C:\Users\Jimmy\AppData\Local\Temp\ipykernel_5616\4259117308.py:2: DtypeWarning: Columns (0: Year-Of-Publication) have mixed types. Specify dtype option on import or set low_memory=False.
#   temp_df = pd.read_csv("dataset\Books.csv")
# Books
#          ISBN                                         Book-Title  \
# 0  0000913154  The Way Things Work: An Illustrated Encycloped...
# 1  0001010565                                    Mog's Christmas
# 2  0001046438                                               Liar
#
#                      Book-Author  Year-Of-Publication             Publisher  \
# 0  C. van Amerongen (translator)               1967.0  Simon &amp; Schuster
# 1                    Judith Kerr               1992.0               Collins
# 2                    Stephen Fry                  NaN      Harpercollins Uk
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0000913154.0...
# 1  http://images.amazon.com/images/P/0001010565.0...
# 2  http://images.amazon.com/images/P/0001046438.0...

# %% [markdown]
# ## fill one missing author's name to "Unknown" in books

# %%
book_df.loc[book_df["Book-Author"].isna(), "Book-Author"] = "Unknown"

# %% [markdown]
# ## change published year to int

# %%
book_df['Year-Of-Publication'] = book_df['Year-Of-Publication'].astype('Int64')

# %% [markdown]
# ## create seperate author and publisher table

# %%
author_df = pd.DataFrame()
author_df["name"] = book_df["Book-Author"].unique()
author_df["author_id"] = author_df.index
author_df = author_df[["author_id", "name"]]

publisher_df = pd.DataFrame()
publisher_df["name"] = book_df["Publisher"].unique()
publisher_df["publisher_id"] = publisher_df.index
publisher_df = publisher_df[["publisher_id", "name"]]

print("Authors")
display(author_df.head(3))
print("Publishers")
display(publisher_df.head(3))
# Out:
# Authors
#    author_id                           name
# 0          0  C. van Amerongen (translator)
# 1          1                    Judith Kerr
# 2          2                    Stephen Fry
# Publishers
#    publisher_id                  name
# 0             0  Simon &amp; Schuster
# 1             1               Collins
# 2             2      Harpercollins Uk

# %% [markdown]
# ## replace author, and publisher with id on books table

# %%
book_df = pd.merge(book_df,author_df, left_on="Book-Author", right_on="name", how="left")
book_df.drop(columns=["Book-Author","name"], inplace=True)

book_df = pd.merge(book_df,publisher_df, left_on="Publisher", right_on="name", how="left")
book_df.drop(columns=["Publisher","name"], inplace=True)
print("Books")
display(book_df.head(3))
# Out:
# Books
#          ISBN                                         Book-Title  \
# 0  0000913154  The Way Things Work: An Illustrated Encycloped...
# 1  0001010565                                    Mog's Christmas
# 2  0001046438                                               Liar
#
#    Year-Of-Publication                                        Image-URL-L  \
# 0                 1967  http://images.amazon.com/images/P/0000913154.0...
# 1                 1992  http://images.amazon.com/images/P/0001010565.0...
# 2                 <NA>  http://images.amazon.com/images/P/0001046438.0...
#
#    author_id  publisher_id
# 0          0             0
# 1          1             1
# 2          2             2

# %% [markdown]
# ## create new book_id then drop the old one (ISBN) on books & ratings tables

# %%
book_df.sort_values("ISBN", inplace=True)
book_df.reset_index(inplace=True)
book_df.rename(columns={"index":"book_id"}, inplace=True)

rating_df = pd.merge(rating_df, book_df[["ISBN", "book_id"]], on="ISBN", how="left")
rating_df.drop(columns="ISBN", inplace=True)

book_df.drop(columns="ISBN", inplace=True)

print("Books")
display(book_df.head(3))

print("Ratings")
display(rating_df.head(3))
# Out:
# Books
#    book_id                                         Book-Title  \
# 0        0  The Way Things Work: An Illustrated Encycloped...
# 1        1                                    Mog's Christmas
# 2        2                                               Liar
#
#    Year-Of-Publication                                        Image-URL-L  \
# 0                 1967  http://images.amazon.com/images/P/0000913154.0...
# 1                 1992  http://images.amazon.com/images/P/0001010565.0...
# 2                 <NA>  http://images.amazon.com/images/P/0001046438.0...
#
#    author_id  publisher_id
# 0          0             0
# 1          1             1
# 2          2             2
# Ratings
#    User-ID  Book-Rating  book_id
# 0        2            0    25028
# 1        8            5       73
# 2        8            0     8211

# %% [markdown]
# ## use birth year instead of age on Users table

# %%
import datetime
user_df["birth_year"] = datetime.datetime.now().year-user_df["Age"]
user_df.drop(columns="Age", inplace=True)

# %% [markdown]
# ## replace the rating == 0 in to NaN in ratings table

# %%
rating_df["Book-Rating"] = rating_df["Book-Rating"].astype("Int64")
rating_df.loc[rating_df["Book-Rating"]==0, "Book-Rating"] = pd.NA
# rating_df.dropna(axis=0, subset=["Book-Rating"], inplace=True)

print("ratings")
display(rating_df.sample(3))
# Out:
# ratings
#          User-ID  Book-Rating  book_id
# 1028196   278418            9    76784
# 229165     61107         <NA>   119585
# 298175     81560         <NA>   119261

# %% [markdown]
# ## rename columns in all tables

# %%
new_columns_map = {"Book-Title" : "name",
                   "Year-Of-Publication" : "published_year",
                   "Image-URL-L" : "image_url"}
book_df.rename(columns=new_columns_map, inplace=True)

new_columns_map = {"Book-Rating" : "book_rating",
                   "User-ID": "user_id"}
rating_df.rename(columns=new_columns_map, inplace=True)

new_columns_map = {"User-ID" : "user_id",
                   "Location" : "location"}
user_df.rename(columns=new_columns_map, inplace=True)

# %% [markdown]
# ## show all tables

# %%
all_df = {"Books" : book_df, 
          "Ratings" : rating_df, 
          "Users" : user_df, 
          "Authors" : author_df, 
          "Publishers" : publisher_df}
for name, df in all_df.items():
    print(name)
    display(df.head(3))
# Out:
# Books
#    book_id                                               name  published_year  \
# 0        0  The Way Things Work: An Illustrated Encycloped...            1967
# 1        1                                    Mog's Christmas            1992
# 2        2                                               Liar            <NA>
#
#                                            image_url  author_id  publisher_id
# 0  http://images.amazon.com/images/P/0000913154.0...          0             0
# 1  http://images.amazon.com/images/P/0001010565.0...          1             1
# 2  http://images.amazon.com/images/P/0001046438.0...          2             2
# Ratings
#    user_id  book_rating  book_id
# 0        2         <NA>    25028
# 1        8            5       73
# 2        8         <NA>     8211
# Users
#    user_id                         location  birth_year
# 0        1               nyc, new york, usa        1992
# 1        2        stockton, california, usa        2008
# 2        3  moscow, yukon territory, russia        1992
# Authors
#    author_id                           name
# 0          0  C. van Amerongen (translator)
# 1          1                    Judith Kerr
# 2          2                    Stephen Fry
# Publishers
#    publisher_id                  name
# 0             0  Simon &amp; Schuster
# 1             1               Collins
# 2             2      Harpercollins Uk

# %% [markdown]
# # Data Trasformation

# %% [markdown]
# ## add new fields to Users table

# %%
import numpy as np
user_df["username"] = pd.NA
user_df["email"] = pd.NA
user_df["user_image"] = pd.NA
user_df = user_df[["user_id", "username", "birth_year", "email", "location", "user_image"]]

# add new user with username and email
new_user = [user_df.user_id.max().item() + 1, "Jimmoi", "2004", "amonthep.se@kkumail.com", "Nongkrusri, kalasin, th", pd.NA]
user_df.loc[len(user_df)] = new_user
print("Users")
user_df.tail(3)
# Out:
# Users
#         user_id username birth_year                    email  \
# 278856   278857     <NA>       1992                     <NA>
# 278857   278858     <NA>       1992                     <NA>
# 278858   278859   Jimmoi       2004  amonthep.se@kkumail.com
#
#                          location user_image
# 278856  knoxville, tennessee, usa       <NA>
# 278857       dublin, n/a, ireland       <NA>
# 278858    Nongkrusri, kalasin, th       <NA>

# %% [markdown]
# ## add new fields to ratings table

# %%
rating_df["comment"] = pd.NA
rating_df["is_favourite"] = False
rating_df = rating_df[["user_id", "book_id", "book_rating", "comment", "is_favourite"]]


# add some random favourite
high_rating_mask = rating_df[rating_df["book_rating"]>8].sample(frac=0.2, random_state=42).index
no_rating_mask = rating_df[rating_df["book_rating"].isna()].sample(frac=0.05, random_state=42).index
mask_index = high_rating_mask.union(no_rating_mask)
rating_df.loc[mask_index,"is_favourite"] = True

# add some random review
mask = rating_df.sample(frac=0.5).index
rating_df.loc[mask,"comment"] = "This is a comment"

print("ratings")
rating_df.head()
# Out:
# ratings
#    user_id  book_id  book_rating            comment  is_favourite
# 0        2    25028         <NA>  This is a comment         False
# 1        8       73            5               <NA>         False
# 2        8     8211         <NA>               <NA>         False
# 3        8    60198         <NA>               <NA>         False
# 4        8    71711         <NA>               <NA>         False

# %% [markdown]
# ## create new table user_wishlist

# %%
user_wishlist_df = user_df.sample(frac=0.005).merge(book_df.sample(frac=0.005, random_state=42), how='cross')
user_wishlist_df = user_wishlist_df[["user_id", "book_id"]]
user_wishlist_df = pd.merge(user_wishlist_df, rating_df, on=["user_id", "book_id"], how="left", indicator=True)
user_wishlist_df = user_wishlist_df[user_wishlist_df['_merge'] == 'left_only']
user_wishlist_df = user_wishlist_df[["user_id", "book_id"]]
user_wishlist_df = user_wishlist_df.sample(frac=0.5)
# user_wishlist_df["is_wish"] = True

print("user_wishlist")
user_wishlist_df.sample(10)
# Out:
# user_wishlist
#          user_id  book_id
# 1846202    74967   269209
# 1831321   224226   269475
# 1779125    41614    28597
# 1680181    88596    10225
# 546516     27531   119867
# 1227634   213086     9489
# 382927     73293    53501
# 572143    101870   154678
# 412504    212950    98139
# 1653077    68889     9252

# %% [markdown]
# ## create new table user read later

# %%
user_readlater_df = user_df.sample(frac=0.005).merge(book_df.sample(frac=0.005, random_state=42), how='cross')
user_readlater_df = user_wishlist_df[["user_id", "book_id"]]
# user_readlater_df["is_readlater"] = True

print("user_readlater")
user_readlater_df.sample(10)
# Out:
# user_readlater
#          user_id  book_id
# 63507     181235   180817
# 254847     63962    60499
# 1342725   222600   158884
# 605592    190237   189657
# 747109     31496    25732
# 617539     62491   118811
# 494527     99316   187009
# 271609    115154   211552
# 1036350   182211   156998
# 563050    155655   206127

# %% [markdown]
# ## rename id column

# %%
book_df.rename(columns={"book_id":"id"}, inplace = True)
author_df.rename(columns={"author_id":"id"}, inplace = True)
publisher_df.rename(columns={"publisher_id":"id"}, inplace = True)
user_df.rename(columns={"user_id":"id"}, inplace = True)

# %%
all_df = {"Books" : book_df, 
          "user_reviews" : rating_df, 
          "Users" : user_df, 
          "Authors" : author_df, 
          "Publishers" : publisher_df,
          "user_wishlists" : user_wishlist_df,
          "user_readlater" : user_readlater_df}
for name, df in all_df.items():
    print(name)
    display(df.head(3))
# Out:
# Books
#    id                                               name  published_year  \
# 0   0  The Way Things Work: An Illustrated Encycloped...            1967
# 1   1                                    Mog's Christmas            1992
# 2   2                                               Liar            <NA>
#
#                                            image_url  author_id  publisher_id
# 0  http://images.amazon.com/images/P/0000913154.0...          0             0
# 1  http://images.amazon.com/images/P/0001010565.0...          1             1
# 2  http://images.amazon.com/images/P/0001046438.0...          2             2
# user_reviews
#    user_id  book_id  book_rating            comment  is_favourite
# 0        2    25028         <NA>  This is a comment         False
# 1        8       73            5               <NA>         False
# 2        8     8211         <NA>               <NA>         False
# Users
#    id username birth_year email                         location user_image
# 0   1     <NA>       1992  <NA>               nyc, new york, usa       <NA>
# 1   2     <NA>       2008  <NA>        stockton, california, usa       <NA>
# 2   3     <NA>       1992  <NA>  moscow, yukon territory, russia       <NA>
# Authors
#    id                           name
# 0   0  C. van Amerongen (translator)
# 1   1                    Judith Kerr
# 2   2                    Stephen Fry
# Publishers
#    id                  name
# 0   0  Simon &amp; Schuster
# 1   1               Collins
# 2   2      Harpercollins Uk
# user_wishlists
#          user_id  book_id
# 1755394   131615   203440
# 699887    186388   193088
# 1653650    68889   121283
# user_readlater
#          user_id  book_id
# 1755394   131615   203440
# 699887    186388   193088
# 1653650    68889   121283

# %% [markdown]
# # save

# %%
book_df
# Out:
#             id                                               name  \
# 0            0  The Way Things Work: An Illustrated Encycloped...
# 1            1                                    Mog's Christmas
# 2            2                                               Liar
# 3            3                       Twopence to Cross the Mersey
# 4            4  T.S. Eliot Reading \The Wasteland\" and Other ...
# ...        ...                                                ...
# 271355  271355                                     Falling Angels
# 271356  271356  It Must've Been Something I Ate: The Return of...
# 271357  271357                        Good Wife Strikes Back, The
# 271358  271358                               The Blockade Runners
# 271359  271359                               The Underground City
#
#         published_year                                          image_url  \
# 0                 1967  http://images.amazon.com/images/P/0000913154.0...
# 1                 1992  http://images.amazon.com/images/P/0001010565.0...
# 2                 <NA>  http://images.amazon.com/images/P/0001046438.0...
# 3                 1992  http://images.amazon.com/images/P/0001046713.0...
# 4                 1993  http://images.amazon.com/images/P/000104687X.0...
# ...                ...                                                ...
# 271355            2001  http://images.amazon.com/images/P/B000234N76.0...
# 271356            2002  http://images.amazon.com/images/P/B000234NC6.0...
# 271357            <NA>  http://images.amazon.com/images/P/B00029DGGO.0...
# 271358            <NA>  http://images.amazon.com/images/P/B0002JV9PY.0...
# 271359            <NA>  http://images.amazon.com/images/P/B0002K6K8O.0...
#
#         author_id  publisher_id
# 0               0             0
# 1               1             1
# 2               2             2
# 3               3             3
# 4               4             3
# ...           ...           ...
# 271355      37862          1942
# 271356      24612          1367
# 271357         13         16802
# 271358       1429         16803
# 271359       1429         16803
#
# [271360 rows x 6 columns]

# %%
output_dir = Path("data_for_db")
for name, df in all_df.items():
    df.to_csv(output_dir/(name+".csv"), index=False)
